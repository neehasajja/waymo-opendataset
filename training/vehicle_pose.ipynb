# %% [markdown]
# <a href="https://colab.research.google.com/github/neehasajja/waymo-opendataset/blob/main/training/vehicle_pose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install waymo-open-dataset-tf-2-6-0

# %%
import os
import pyarrow.parquet as pq

# Set the path to the metadata file
metadata_file_path = '/content/drive/MyDrive/training/vehicle_pose/_metadata'

# Read the metadata file
metadata_file = pq.ParquetFile(metadata_file_path)

# Get the metadata
file_metadata = metadata_file.metadata
schema_metadata = file_metadata.metadata

# Print the metadata
print("File metadata:", file_metadata)
print("Schema metadata:", schema_metadata)
# Out:
# File metadata: <pyarrow._parquet.FileMetaData object at 0x7f1e5998f3b0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 158081
#   num_row_groups: 798
#   format_version: 2.6
#   serialized_size: 655099
# ...

# %%
import os
import pyarrow.parquet as pq
import tensorflow as tf

# Set the path to the directory containing the parquet files
dir_path = '/content/drive/MyDrive/training/vehicle_pose/'
# Get a list of all the files in the directory
files = os.listdir(dir_path)

# Loop through each file and extract metadata
for filename in files:
    # Skip directories
    if os.path.isdir(os.path.join(dir_path, filename)):
        continue
        
    # Check if the file is a parquet file
    if filename.endswith('.parquet'):
        # Read the parquet file
        parquet_file = pq.ParquetFile(os.path.join(dir_path, filename))

        # Get the metadata
        metadata = parquet_file.metadata

        # Print the metadata
        print("File:", filename)
        print(metadata)
# Out:
# Streaming output truncated to the last 5000 lines.
# File: 11971497357570544465_1200_000_1220_000.parquet
# ...
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 175
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571
# File: 13731697468004921673_4920_000_4940_000.parquet
# ...
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 198
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571
# File: 13196796799137805454_3036_940_3056_940.parquet
# ...
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 197
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571
# File: 12179768245749640056_5561_070_5581_070.parquet
# ...
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 199
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571
# File: 1357883579772440606_2365_000_2385_000.parquet
# ...

# %%
import os
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the directory containing the parquet files
dir_path = '/content/drive/MyDrive/training/vehicle_pose/'

# Get a list of all the files in the directory
files = os.listdir(dir_path)

# Loop through each file and extract metadata
for filename in files:
    # Skip directories
    if os.path.isdir(os.path.join(dir_path, filename)):
        continue
        
    # Check if the file is a parquet file
    if filename.endswith('.parquet'):
        # Read the parquet file
        parquet_file = pq.ParquetFile(os.path.join(dir_path, filename))

        # Get the table from the file
        table = parquet_file.read()

        # Convert the table to a Pandas DataFrame
        df = table.to_pandas()

        # Calculate column statistics
        statistics = df.describe()

        # Print the statistics
        print("File:", filename)
        print(statistics)
# Out:
# Streaming output truncated to the last 5000 lines.
# File: 14830022845193837364_3488_060_3508_060.parquet
#        key.frame_timestamp_micros
# count                1.990000e+02
# mean                 1.508718e+15
# std                  5.759189e+06
# min                  1.508718e+15
# 25%                  1.508718e+15
# 50%                  1.508718e+15
# 75%                  1.508718e+15
# max                  1.508718e+15
# File: 14753089714893635383_873_600_893_600.parquet
#        key.frame_timestamp_micros
# count                1.970000e+02
# mean                 1.507946e+15
# std                  5.742488e+06
# min                  1.507946e+15
# 25%                  1.507946e+15
# 50%                  1.507946e+15
# 75%                  1.507946e+15
# max                  1.507946e+15
# File: 141184560845819621_10582_560_10602_560.parquet
#        key.frame_timestamp_micros
# count                1.970000e+02
# mean                 1.509064e+15
# ...

# %%
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the Parquet file
parquet_file_path = '/content/drive/MyDrive/training/vehicle_pose/file1.parquet'

# Read the Parquet file into a Pyarrow table
table = pq.read_table(parquet_file_path)

# Convert the table to a Pandas DataFrame
df = table.to_pandas()

# Print the first 10 rows of the DataFrame
print(df.head(10))
# Out:
#                                                                 key.segment_context_name  \
# index
# 18418533015310829002_480_000_500_000;1550088112...  18418533015310829002_480_000_500_000
# 18418533015310829002_480_000_500_000;1550088112...  18418533015310829002_480_000_500_000
# 18418533015310829002_480_000_500_000;1550088112...  18418533015310829002_480_000_500_000
# 18418533015310829002_480_000_500_000;1550088112...  18418533015310829002_480_000_500_000
# 18418533015310829002_480_000_500_000;1550088112...  18418533015310829002_480_000_500_000
# 18418533015310829002_480_000_500_000;1550088112...  18418533015310829002_480_000_500_000
# 18418533015310829002_480_000_500_000;1550088112...  18418533015310829002_480_000_500_000
# 18418533015310829002_480_000_500_000;1550088113...  18418533015310829002_480_000_500_000
# 18418533015310829002_480_000_500_000;1550088113...  18418533015310829002_480_000_500_000
# ...

# %%
import seaborn as sns

# Load the parquet file into a pandas dataframe
df = pd.read_parquet('/content/drive/MyDrive/training/vehicle_pose/file1.parquet')

# Plot a countplot of the "key.segment_context_name" column
sns.countplot(y='key.segment_context_name', data=df)
# Out:
# <Axes: xlabel='count', ylabel='key.segment_context_name'>

# %%
import seaborn as sns

# Load the parquet file into a pandas dataframe
df = pd.read_parquet('/content/drive/MyDrive/training/vehicle_pose')

# Plot a countplot of the "key.segment_context_name" column
sns.countplot(y='key.segment_context_name', data=df)
# Out:
# <Axes: xlabel='count', ylabel='key.segment_context_name'>

# %%
import matplotlib.pyplot as plt

# Get the timestamps and convert them to datetime objects
timestamps = pd.to_datetime(df['key.frame_timestamp_micros'], unit='us')

# Create the plot
plt.plot(timestamps, df.index)
plt.xlabel('Timestamp')
plt.ylabel('Index')
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract the x, y, and z coordinates from the transform column of the DataFrame
x_coords = [row[0] for row in df['[VehiclePoseComponent].world_from_vehicle.transform']]
y_coords = [row[1] for row in df['[VehiclePoseComponent].world_from_vehicle.transform']]
z_coords = [row[2] for row in df['[VehiclePoseComponent].world_from_vehicle.transform']]

# Create a scatter plot with x, y, and z coordinates
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_coords, y_coords, z_coords, c='r', marker='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
