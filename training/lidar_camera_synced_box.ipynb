# %% [markdown]
# <a href="https://colab.research.google.com/github/neehasajja/waymo-opendataset/blob/main/training/lidar_camera_synced_box.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install waymo-open-dataset-tf-2-6-0

# %%
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the Parquet file
parquet_file_path = '/content/drive/MyDrive/training/lidar_camera_synced_box/file1.parquet'

# Read the Parquet file into a Pyarrow table
table = pq.read_table(parquet_file_path)

# Convert the table to a Pandas DataFrame
df = table.to_pandas()

# Print the first 10 rows of the DataFrame
print(df.head(10))
# Out:
#                                                                key.segment_context_name  \
# index
# 16102220208346880_1420_000_1440_000;15542328851...  16102220208346880_1420_000_1440_000
# 16102220208346880_1420_000_1440_000;15542328851...  16102220208346880_1420_000_1440_000
# 16102220208346880_1420_000_1440_000;15542328851...  16102220208346880_1420_000_1440_000
# 16102220208346880_1420_000_1440_000;15542328851...  16102220208346880_1420_000_1440_000
# 16102220208346880_1420_000_1440_000;15542328851...  16102220208346880_1420_000_1440_000
# 16102220208346880_1420_000_1440_000;15542328851...  16102220208346880_1420_000_1440_000
# 16102220208346880_1420_000_1440_000;15542328851...  16102220208346880_1420_000_1440_000
# 16102220208346880_1420_000_1440_000;15542328851...  16102220208346880_1420_000_1440_000
# 16102220208346880_1420_000_1440_000;15542328851...  16102220208346880_1420_000_1440_000
# ...

# %%
print(df.columns)
# Out:
# Index(['key.segment_context_name', 'key.frame_timestamp_micros',
#        'key.laser_object_id',
#        '[LiDARCameraSyncedBoxComponent].most_visible_camera_name',
#        '[LiDARCameraSyncedBoxComponent].camera_synced_box.center.x',
#        '[LiDARCameraSyncedBoxComponent].camera_synced_box.center.y',
#        '[LiDARCameraSyncedBoxComponent].camera_synced_box.center.z',
#        '[LiDARCameraSyncedBoxComponent].camera_synced_box.size.x',
#        '[LiDARCameraSyncedBoxComponent].camera_synced_box.size.y',
#        '[LiDARCameraSyncedBoxComponent].camera_synced_box.size.z',
#        '[LiDARCameraSyncedBoxComponent].camera_synced_box.heading'],
#       dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
df = pd.read_parquet('/content/drive/MyDrive/training/lidar_camera_synced_box/file1.parquet')

# Plot the box center coordinates against time
plt.plot(df['key.frame_timestamp_micros'], df['[LiDARCameraSyncedBoxComponent].camera_synced_box.center.x'], label='x')
plt.plot(df['key.frame_timestamp_micros'], df['[LiDARCameraSyncedBoxComponent].camera_synced_box.center.y'], label='y')
plt.plot(df['key.frame_timestamp_micros'], df['[LiDARCameraSyncedBoxComponent].camera_synced_box.center.z'], label='z')
plt.legend()
plt.xlabel('Time (microseconds)')
plt.ylabel('Box center coordinates (m)')
plt.show()
