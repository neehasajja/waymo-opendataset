# %% [markdown]
# <a href="https://colab.research.google.com/github/neehasajja/waymo-opendataset/blob/main/training/lidar.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install waymo-open-dataset-tf-2-6-0

# %%
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the Parquet file
parquet_file_path = '/content/drive/MyDrive/training/lidar/file1.parquet'

# Read the Parquet file into a Pyarrow table
table = pq.read_table(parquet_file_path)

# Convert the table to a Pandas DataFrame
df = table.to_pandas()

# Print the first 10 rows of the DataFrame
print(df.head(10))
# Out:
#                                                                key.segment_context_name  \
# index
# 15832924468527961_1564_160_1584_160;15076788268...  15832924468527961_1564_160_1584_160
# 15832924468527961_1564_160_1584_160;15076788268...  15832924468527961_1564_160_1584_160
# 15832924468527961_1564_160_1584_160;15076788268...  15832924468527961_1564_160_1584_160
# 15832924468527961_1564_160_1584_160;15076788268...  15832924468527961_1564_160_1584_160
# 15832924468527961_1564_160_1584_160;15076788268...  15832924468527961_1564_160_1584_160
# 15832924468527961_1564_160_1584_160;15076788269...  15832924468527961_1564_160_1584_160
# 15832924468527961_1564_160_1584_160;15076788269...  15832924468527961_1564_160_1584_160
# 15832924468527961_1564_160_1584_160;15076788269...  15832924468527961_1564_160_1584_160
# 15832924468527961_1564_160_1584_160;15076788269...  15832924468527961_1564_160_1584_160
# ...

# %%
print(df.columns)
# Out:
# Index(['key.segment_context_name', 'key.frame_timestamp_micros',
#        'key.laser_name', '[LiDARComponent].range_image_return1.values',
#        '[LiDARComponent].range_image_return1.shape',
#        '[LiDARComponent].range_image_return2.values',
#        '[LiDARComponent].range_image_return2.shape'],
#       dtype='object')
