# %% [markdown]
# <a href="https://colab.research.google.com/github/neehasajja/waymo-opendataset/blob/main/training/camera_image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install waymo-open-dataset-tf-2-6-0

# %%
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the Parquet file
parquet_file_path = '/content/drive/MyDrive/training/camera_hkp/file1.parquet'

# Read the Parquet file into a Pyarrow table
table = pq.read_table(parquet_file_path)

# Convert the table to a Pandas DataFrame
df = table.to_pandas()

# Print the first 10 rows of the DataFrame
print(df.head(10))
# Out:
#                                                                 key.segment_context_name  \
# index
# 616184888931414205_2020_000_2040_000;1557934036...  616184888931414205_2020_000_2040_000
# 616184888931414205_2020_000_2040_000;1557934036...  616184888931414205_2020_000_2040_000
# 616184888931414205_2020_000_2040_000;1557934036...  616184888931414205_2020_000_2040_000
# 616184888931414205_2020_000_2040_000;1557934036...  616184888931414205_2020_000_2040_000
# 616184888931414205_2020_000_2040_000;1557934036...  616184888931414205_2020_000_2040_000
# 616184888931414205_2020_000_2040_000;1557934036...  616184888931414205_2020_000_2040_000
# 616184888931414205_2020_000_2040_000;1557934036...  616184888931414205_2020_000_2040_000
# 616184888931414205_2020_000_2040_000;1557934036...  616184888931414205_2020_000_2040_000
# 616184888931414205_2020_000_2040_000;1557934036...  616184888931414205_2020_000_2040_000
# ...

# %%
print(df.columns)
# Out:
# Index(['key.segment_context_name', 'key.frame_timestamp_micros',
#        'key.camera_name', 'key.camera_object_id',
#        '[CameraHumanKeypointsComponent].camera_keypoints[*].type',
#        '[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.x',
#        '[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.y',
#        '[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.visibility.is_occluded',
#        '[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.x',
#        '[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.y',
#        '[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.z',
#        '[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.visibility.is_occluded'],
#       dtype='object')

# %%
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the Parquet file
parquet_file_path = '/content/drive/MyDrive/training/camera_image/file1.parquet'

# Read the Parquet file into a Pyarrow table
table = pq.read_table(parquet_file_path)

# Convert the table to a Pandas DataFrame
df = table.to_pandas()

# Print the first 10 rows of the DataFrame
print(df.head(10))
# Out:
#                                                                 key.segment_context_name  \
# index
# 268278198029493143_1400_000_1420_000;1558151203...  268278198029493143_1400_000_1420_000
# 268278198029493143_1400_000_1420_000;1558151203...  268278198029493143_1400_000_1420_000
# 268278198029493143_1400_000_1420_000;1558151203...  268278198029493143_1400_000_1420_000
# 268278198029493143_1400_000_1420_000;1558151203...  268278198029493143_1400_000_1420_000
# 268278198029493143_1400_000_1420_000;1558151203...  268278198029493143_1400_000_1420_000
# 268278198029493143_1400_000_1420_000;1558151203...  268278198029493143_1400_000_1420_000
# 268278198029493143_1400_000_1420_000;1558151203...  268278198029493143_1400_000_1420_000
# 268278198029493143_1400_000_1420_000;1558151203...  268278198029493143_1400_000_1420_000
# 268278198029493143_1400_000_1420_000;1558151203...  268278198029493143_1400_000_1420_000
# ...

# %%
print(df.columns)
# Out:
# Index(['key.segment_context_name', 'key.frame_timestamp_micros',
#        'key.camera_name', '[CameraImageComponent].image',
#        '[CameraImageComponent].pose.transform',
#        '[CameraImageComponent].velocity.linear_velocity.x',
#        '[CameraImageComponent].velocity.linear_velocity.y',
#        '[CameraImageComponent].velocity.linear_velocity.z',
#        '[CameraImageComponent].velocity.angular_velocity.x',
#        '[CameraImageComponent].velocity.angular_velocity.y',
#        '[CameraImageComponent].velocity.angular_velocity.z',
#        '[CameraImageComponent].pose_timestamp',
#        '[CameraImageComponent].rolling_shutter_params.shutter',
#        '[CameraImageComponent].rolling_shutter_params.camera_trigger_time',
#        '[CameraImageComponent].rolling_shutter_params.camera_readout_done_time'],
#       dtype='object')

# %%
import pandas as pd
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# Set the path to the Parquet file
parquet_file_path = '/content/drive/MyDrive/training/camera_image/file1.parquet'

# Load the Parquet file into a Pandas DataFrame
camera_image = pd.read_parquet(parquet_file_path)

# Extract the camera image
img = camera_image.iloc[0]['[CameraImageComponent].image']

# Convert the camera image from bytes to a NumPy array
nparr = np.frombuffer(img, np.uint8)
img_np = cv2.imdecode(nparr, cv2.IMREAD_COLOR)

# Resize the image
resized_img = cv2.resize(img_np, (640, 360))

# Display the resized image
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x7FD2B7A38700>

# %%
import pandas as pd
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# Set the path to the Parquet file
parquet_file_path = '/content/drive/MyDrive/training/camera_image/f5.parquet'

# Load the Parquet file into a Pandas DataFrame
camera_image = pd.read_parquet(parquet_file_path)

# Extract the camera image
img = camera_image.iloc[0]['[CameraImageComponent].image']

# Convert the camera image from bytes to a NumPy array
nparr = np.frombuffer(img, np.uint8)
img_np = cv2.imdecode(nparr, cv2.IMREAD_COLOR)

# Resize the image
resized_img = cv2.resize(img_np, (640, 360))

# Display the resized image
cv2_imshow(resized_img)
# Out:
# <PIL.Image.Image image mode=RGB size=640x360 at 0x7FD378D5FA90>

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from waymo_open_dataset import dataset_pb2

# Load the camera image and associated metadata from a Parquet file
camera_image_path = '/content/drive/MyDrive/training/camera_image/file1.parquet'
df = pd.read_parquet(camera_image_path)
camera_image_data = np.frombuffer(df.iloc[0]['[CameraImageComponent].image'], dtype=np.uint8)
metadata = dataset_pb2.CameraImage()
if 'metadata' in df:
    metadata.ParseFromString(df.iloc[0]['metadata'])

# Display metadata and dimensions of the camera image
print(metadata)
print(camera_image_data.shape)
# Out:
# (575321,)

# %%
import pyarrow.parquet as pq
import pandas as pd
import numpy as np

# Load the parquet file into a pandas dataframe
parquet_file = '/content/drive/MyDrive/training/camera_image/file1.parquet'
df = pq.read_table(parquet_file).to_pandas()

# Extract the camera images from the dataframe
images = np.array(df['[CameraImageComponent].image'].values.tolist())
