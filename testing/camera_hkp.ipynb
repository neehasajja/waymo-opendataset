# %% [markdown]
# <a href="https://colab.research.google.com/github/neehasajja/waymo-opendataset/blob/main/testing/camera_hkp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install waymo-open-dataset-tf-2-6-0

# %%
import os
import pyarrow.parquet as pq

# Set the path to the metadata file
metadata_file_path = '/content/drive/MyDrive/testing/camera_hkp/_metadata'

# Read the metadata file
metadata_file = pq.ParquetFile(metadata_file_path)

# Get the metadata
file_metadata = metadata_file.metadata
schema_metadata = file_metadata.metadata

# Print the metadata
print("File metadata:", file_metadata)
print("Schema metadata:", schema_metadata)
# Out:
# File metadata: <pyarrow._parquet.FileMetaData object at 0x7efbe80ae270>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 16
#   format_version: 2.6
#   serialized_size: 40312
# Schema metadata: {b'ARROW:schema': b'...', b'pandas': b'{"column_indexes": [{"field_name": null, "metadata": {"encoding": "UTF-8"}, "name": null, "numpy_type": "object", "pandas_type": "unicode"}], "columns": [{"name": "index", "field_name": "index", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "key.segment_context_name", "field_name": "key.segment_context_name", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "key.frame_timestamp_micros", "field_name": "key.frame_timestamp_micros", "metadata": null, "numpy_type": "int64", "pandas_type": "int64"}, {"name": "key.camera_name", "field_name": "key.camera_name", "metadata": null, "numpy_type": "int8", "pandas_type": "int8"}, {"name": "key.camera_object_id", "field_name": "key.camera_object_id", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "[CameraHumanKeypointsComponent].camera_keypoints[*].type", "field_name": "[CameraHumanKeypointsComponent].camera_keypoints[*].type", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.x", "field_name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.x", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.y", "field_name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.y", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.visibility.is_occluded", "field_name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.visibility.is_occluded", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.x", "field_name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.x", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.y", "field_name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.y", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.z", "field_name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.z", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.visibility.is_occluded", "field_name": "[CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.visibility.is_occluded", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}], "creator": {"library": "pyarrow", "version": "10.0.1"}, "index_columns": ["index"], "pandas_version": "1.1.5"}'}

# %%
import os
import pyarrow.parquet as pq
import tensorflow as tf

# Set the path to the directory containing the parquet files
dir_path = '/content/drive/MyDrive/testing/camera_hkp/'
# Get a list of all the files in the directory
files = os.listdir(dir_path)

# Loop through each file and extract metadata
for filename in files:
    # Skip directories
    if os.path.isdir(os.path.join(dir_path, filename)):
        continue
        
    # Check if the file is a parquet file
    if filename.endswith('.parquet'):
        # Read the parquet file
        parquet_file = pq.ParquetFile(os.path.join(dir_path, filename))

        # Get the metadata
        metadata = parquet_file.metadata

        # Print the metadata
        print("File:", filename)
        print(metadata)
# Out:
# File: 17136775999940024630_4860_000_4880_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b92af90>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 8993680275027614595_2520_000_2540_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b932360>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 5638240639308158118_4220_000_4240_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b92af90>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 14188689528137485670_2660_000_2680_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b9324a0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 10980133015080705026_780_000_800_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b92af90>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 18149616047892103767_2460_000_2480_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b932310>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 5026942594071056992_3120_000_3140_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b9321d0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 11987368976578218644_1340_000_1360_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b932040>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 15272375112495403395_620_000_640_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b932270>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 2601205676330128831_4880_000_4900_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efbeb6a9130>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 7247823803417339098_2320_000_2340_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b932270>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 10504764403039842352_460_000_480_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b9324f0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 8688567562597583972_940_000_960_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efc0792ccc0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 14737335824319407706_1980_000_2000_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b932400>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 4140965781175793864_460_000_480_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efb7b932310>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618
# File: 17792628511034220885_2360_000_2380_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7efc0792ccc0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 13
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 11618

# %%
import os
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the directory containing the parquet files
dir_path = '/content/drive/MyDrive/testing/camera_hkp/'

# Get a list of all the files in the directory
files = os.listdir(dir_path)

# Loop through each file and extract metadata
for filename in files:
    # Skip directories
    if os.path.isdir(os.path.join(dir_path, filename)):
        continue
        
    # Check if the file is a parquet file
    if filename.endswith('.parquet'):
        # Read the parquet file
        parquet_file = pq.ParquetFile(os.path.join(dir_path, filename))

        # Get the table from the file
        table = parquet_file.read()

        # Convert the table to a Pandas DataFrame
        df = table.to_pandas()

        # Calculate column statistics
        statistics = df.describe()

        # Print the statistics
        print("File:", filename)
        print(statistics)
# Out:
# File: 17136775999940024630_4860_000_4880_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 8993680275027614595_2520_000_2540_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 5638240639308158118_4220_000_4240_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 14188689528137485670_2660_000_2680_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 10980133015080705026_780_000_800_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 18149616047892103767_2460_000_2480_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 5026942594071056992_3120_000_3140_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 11987368976578218644_1340_000_1360_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 15272375112495403395_620_000_640_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 2601205676330128831_4880_000_4900_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 7247823803417339098_2320_000_2340_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 10504764403039842352_460_000_480_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 8688567562597583972_940_000_960_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 14737335824319407706_1980_000_2000_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 4140965781175793864_460_000_480_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
# File: 17792628511034220885_2360_000_2380_000.parquet
#        key.frame_timestamp_micros  key.camera_name
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN

# %%
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the Parquet file
parquet_file_path = '/content/drive/MyDrive/testing/camera_hkp/file1.parquet'

# Read the Parquet file into a Pyarrow table
table = pq.read_table(parquet_file_path)

# Convert the table to a Pandas DataFrame
df = table.to_pandas()

# Print the first 10 rows of the DataFrame
print(df.head(10))
# Out:
# Empty DataFrame
# Columns: [key.segment_context_name, key.frame_timestamp_micros, key.camera_name, key.camera_object_id, [CameraHumanKeypointsComponent].camera_keypoints[*].type, [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.x, [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.location_px.y, [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_2d.visibility.is_occluded, [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.x, [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.y, [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.location_m.z, [CameraHumanKeypointsComponent].camera_keypoints[*].keypoint_3d.visibility.is_occluded]
# Index: []
