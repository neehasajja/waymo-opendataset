# %% [markdown]
# <a href="https://colab.research.google.com/github/neehasajja/waymo-opendataset/blob/main/testing/vehiclepose.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install waymo-open-dataset-tf-2-6-0

# %%
# !pip install tensorflow

# %%
import os
import pyarrow.parquet as pq

# Set the path to the metadata file
metadata_file_path = '/content/drive/MyDrive/testing/vehicle_pose/_metadata'

# Read the metadata file
metadata_file = pq.ParquetFile(metadata_file_path)

# Get the metadata
file_metadata = metadata_file.metadata
schema_metadata = file_metadata.metadata

# Print the metadata
print("File metadata:", file_metadata)
print("Schema metadata:", schema_metadata)
# Out:
# File metadata: <pyarrow._parquet.FileMetaData object at 0x7ff16fd0a090>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 3101
#   num_row_groups: 16
#   format_version: 2.6
#   serialized_size: 16018
# Schema metadata: {b'ARROW:schema': b'...', b'pandas': b'{"column_indexes": [{"field_name": null, "metadata": {"encoding": "UTF-8"}, "name": null, "numpy_type": "object", "pandas_type": "unicode"}], "columns": [{"name": "index", "field_name": "index", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "key.segment_context_name", "field_name": "key.segment_context_name", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}, {"name": "key.frame_timestamp_micros", "field_name": "key.frame_timestamp_micros", "metadata": null, "numpy_type": "int64", "pandas_type": "int64"}, {"name": "[VehiclePoseComponent].world_from_vehicle.transform", "field_name": "[VehiclePoseComponent].world_from_vehicle.transform", "metadata": null, "numpy_type": "object", "pandas_type": "bytes"}], "creator": {"library": "pyarrow", "version": "10.0.1"}, "index_columns": ["index"], "pandas_version": "1.1.5"}'}

# %%
import os
import pyarrow.parquet as pq
import tensorflow as tf

# Set the path to the directory containing the parquet files
dir_path = '/content/drive/MyDrive/testing/vehicle_pose/'
# Get a list of all the files in the directory
files = os.listdir(dir_path)

# Loop through each file and extract metadata
for filename in files:
    # Skip directories
    if os.path.isdir(os.path.join(dir_path, filename)):
        continue
        
    # Check if the file is a parquet file
    if filename.endswith('.parquet'):
        # Read the parquet file
        parquet_file = pq.ParquetFile(os.path.join(dir_path, filename))

        # Get the metadata
        metadata = parquet_file.metadata

        # Print the metadata
        print("File:", filename)
        print(metadata)
# Out:
# File: 14188689528137485670_2660_000_2680_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff18d1a42c0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 198
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571
# File: 11987368976578218644_1340_000_1360_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff18d1a4400>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 198
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571
# File: 14737335824319407706_1980_000_2000_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff1d553a720>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 199
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571
# File: 10980133015080705026_780_000_800_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff18d1a4270>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 198
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3563
# File: 10504764403039842352_460_000_480_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff200ef1c70>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 166
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3563
# File: 15272375112495403395_620_000_640_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff18d1a4450>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 196
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3563
# File: 17792628511034220885_2360_000_2380_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff200ef1c70>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 172
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571
# File: 17136775999940024630_4860_000_4880_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff18d1a4270>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 188
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571
# File: 5026942594071056992_3120_000_3140_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff18d1a4450>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 199
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3567
# File: 8688567562597583972_940_000_960_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff18d1a4270>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 198
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3559
# File: 2601205676330128831_4880_000_4900_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff1d553a720>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 199
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3567
# File: 7247823803417339098_2320_000_2340_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff18d1a44a0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 199
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3567
# File: 4140965781175793864_460_000_480_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff200ef1c70>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 196
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3559
# File: 5638240639308158118_4220_000_4240_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff18d1a4630>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 199
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3567
# File: 8993680275027614595_2520_000_2540_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff200ef1c70>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 198
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3567
# File: file1.parquet
# <pyarrow._parquet.FileMetaData object at 0x7ff1d553a720>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 4
#   num_rows: 198
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 3571

# %%
import os
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the directory containing the parquet files
dir_path = '/content/drive/MyDrive/testing/vehicle_pose/'

# Get a list of all the files in the directory
files = os.listdir(dir_path)

# Loop through each file and extract metadata
for filename in files:
    # Skip directories
    if os.path.isdir(os.path.join(dir_path, filename)):
        continue
        
    # Check if the file is a parquet file
    if filename.endswith('.parquet'):
        # Read the parquet file
        parquet_file = pq.ParquetFile(os.path.join(dir_path, filename))

        # Get the table from the file
        table = parquet_file.read()

        # Convert the table to a Pandas DataFrame
        df = table.to_pandas()

        # Calculate column statistics
        statistics = df.describe()

        # Print the statistics
        print("File:", filename)
        print(statistics)
# Out:
# File: 14188689528137485670_2660_000_2680_000.parquet
#        key.frame_timestamp_micros
# count                1.980000e+02
# mean                 1.555688e+15
# std                  5.719822e+06
# min                  1.555688e+15
# 25%                  1.555688e+15
# 50%                  1.555688e+15
# 75%                  1.555688e+15
# max                  1.555688e+15
# File: 11987368976578218644_1340_000_1360_000.parquet
#        key.frame_timestamp_micros
# count                1.980000e+02
# mean                 1.557240e+15
# std                  5.720072e+06
# min                  1.557240e+15
# 25%                  1.557240e+15
# 50%                  1.557240e+15
# 75%                  1.557240e+15
# max                  1.557240e+15
# File: 14737335824319407706_1980_000_2000_000.parquet
#        key.frame_timestamp_micros
# count                1.990000e+02
# mean                 1.556068e+15
# std                  5.758847e+06
# min                  1.556068e+15
# 25%                  1.556068e+15
# 50%                  1.556068e+15
# 75%                  1.556068e+15
# max                  1.556068e+15
# File: 10980133015080705026_780_000_800_000.parquet
#        key.frame_timestamp_micros
# count                1.980000e+02
# mean                 1.557159e+15
# std                  5.730188e+06
# min                  1.557159e+15
# 25%                  1.557159e+15
# 50%                  1.557159e+15
# 75%                  1.557159e+15
# max                  1.557159e+15
# File: 10504764403039842352_460_000_480_000.parquet
#        key.frame_timestamp_micros
# count                1.660000e+02
# mean                 1.558061e+15
# std                  6.036114e+06
# min                  1.558061e+15
# 25%                  1.558061e+15
# 50%                  1.558061e+15
# 75%                  1.558061e+15
# max                  1.558061e+15
# File: 15272375112495403395_620_000_640_000.parquet
#        key.frame_timestamp_micros
# count                1.960000e+02
# mean                 1.559189e+15
# std                  5.720942e+06
# min                  1.559189e+15
# 25%                  1.559189e+15
# 50%                  1.559189e+15
# 75%                  1.559189e+15
# max                  1.559189e+15
# File: 17792628511034220885_2360_000_2380_000.parquet
#        key.frame_timestamp_micros
# count                1.720000e+02
# mean                 1.555039e+15
# std                  6.078925e+06
# min                  1.555039e+15
# 25%                  1.555039e+15
# 50%                  1.555039e+15
# 75%                  1.555039e+15
# max                  1.555039e+15
# File: 17136775999940024630_4860_000_4880_000.parquet
#        key.frame_timestamp_micros
# count                1.880000e+02
# mean                 1.555382e+15
# std                  5.738289e+06
# min                  1.555382e+15
# 25%                  1.555382e+15
# 50%                  1.555382e+15
# 75%                  1.555382e+15
# max                  1.555382e+15
# File: 5026942594071056992_3120_000_3140_000.parquet
#        key.frame_timestamp_micros
# count                1.990000e+02
# mean                 1.555462e+15
# std                  5.758945e+06
# min                  1.555462e+15
# 25%                  1.555462e+15
# 50%                  1.555462e+15
# 75%                  1.555462e+15
# max                  1.555462e+15
# File: 8688567562597583972_940_000_960_000.parquet
#        key.frame_timestamp_micros
# count                1.980000e+02
# mean                 1.555217e+15
# std                  5.730125e+06
# min                  1.555217e+15
# 25%                  1.555217e+15
# 50%                  1.555217e+15
# 75%                  1.555217e+15
# max                  1.555217e+15
# File: 2601205676330128831_4880_000_4900_000.parquet
#        key.frame_timestamp_micros
# count                1.990000e+02
# mean                 1.555183e+15
# std                  5.749150e+06
# min                  1.555183e+15
# 25%                  1.555183e+15
# 50%                  1.555183e+15
# 75%                  1.555183e+15
# max                  1.555183e+15
# File: 7247823803417339098_2320_000_2340_000.parquet
#        key.frame_timestamp_micros
# count                1.990000e+02
# mean                 1.557198e+15
# std                  5.759558e+06
# min                  1.557198e+15
# 25%                  1.557198e+15
# 50%                  1.557198e+15
# 75%                  1.557198e+15
# max                  1.557198e+15
# File: 4140965781175793864_460_000_480_000.parquet
#        key.frame_timestamp_micros
# count                1.960000e+02
# mean                 1.559189e+15
# std                  5.757660e+06
# min                  1.559189e+15
# 25%                  1.559189e+15
# 50%                  1.559189e+15
# 75%                  1.559189e+15
# max                  1.559189e+15
# File: 5638240639308158118_4220_000_4240_000.parquet
#        key.frame_timestamp_micros
# count                1.990000e+02
# mean                 1.555268e+15
# std                  5.757322e+06
# min                  1.555268e+15
# 25%                  1.555268e+15
# 50%                  1.555268e+15
# 75%                  1.555268e+15
# max                  1.555268e+15
# File: 8993680275027614595_2520_000_2540_000.parquet
#        key.frame_timestamp_micros
# count                1.980000e+02
# mean                 1.555280e+15
# std                  5.719616e+06
# min                  1.555280e+15
# 25%                  1.555280e+15
# 50%                  1.555280e+15
# 75%                  1.555280e+15
# max                  1.555280e+15
# File: file1.parquet
#        key.frame_timestamp_micros
# count                1.980000e+02
# mean                 1.555707e+15
# std                  5.729627e+06
# min                  1.555707e+15
# 25%                  1.555707e+15
# 50%                  1.555707e+15
# 75%                  1.555707e+15
# max                  1.555707e+15

# %%
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the Parquet file
parquet_file_path = '/content/drive/MyDrive/testing/vehicle_pose/file1.parquet'

# Read the Parquet file into a Pyarrow table
table = pq.read_table(parquet_file_path)

# Convert the table to a Pandas DataFrame
df = table.to_pandas()

# Print the first 10 rows of the DataFrame
print(df.head(10))
# Out:
#                                                                   key.segment_context_name  \
# index
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
# 18149616047892103767_2460_000_2480_000;15557066...  18149616047892103767_2460_000_2480_000
#
#                                                     key.frame_timestamp_micros  \
# index
# 18149616047892103767_2460_000_2480_000;15557066...            1555706641900051
# 18149616047892103767_2460_000_2480_000;15557066...            1555706642000036
# 18149616047892103767_2460_000_2480_000;15557066...            1555706642100016
# 18149616047892103767_2460_000_2480_000;15557066...            1555706642200004
# 18149616047892103767_2460_000_2480_000;15557066...            1555706642299986
# 18149616047892103767_2460_000_2480_000;15557066...            1555706642399968
# 18149616047892103767_2460_000_2480_000;15557066...            1555706642499948
# 18149616047892103767_2460_000_2480_000;15557066...            1555706642599895
# 18149616047892103767_2460_000_2480_000;15557066...            1555706642699881
# 18149616047892103767_2460_000_2480_000;15557066...            1555706642799864
#
#                                                    [VehiclePoseComponent].world_from_vehicle.transform
# index
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999633710018745, 0.0006800590995104257, -...
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999625483450193, 0.000680160205680233, -0...
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999625483450193, 0.000680160205680233, -0...
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999625483450193, 0.0006809873838318646, -...
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999625483450193, 0.0006809873838318646, -...
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999633710018745, 0.0006800590995104257, -...
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999641844593714, 0.0006791491916904984, -...
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999633710018745, 0.0006800590995104257, -...
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999625483450193, 0.000680160205680233, -0...
# 18149616047892103767_2460_000_2480_000;15557066...  [-0.9999633710018745, 0.0006800590995104257, -...

# %%
import seaborn as sns

# Load the parquet file into a pandas dataframe
df = pd.read_parquet('path/to/your/parquet/file.parquet')

# Plot a countplot of the "key.segment_context_name" column
sns.countplot(y='key.segment_context_name', data=df)
# Out:
# <Axes: xlabel='count', ylabel='key.segment_context_name'>

# %%
import seaborn as sns

# Load the parquet file into a pandas dataframe
df = pd.read_parquet('/content/drive/MyDrive/testing/vehicle_pose')

# Plot a countplot of the "key.segment_context_name" column
sns.countplot(y='key.segment_context_name', data=df)
# Out:
# <Axes: xlabel='count', ylabel='key.segment_context_name'>

# %%
import matplotlib.pyplot as plt

# Get the timestamps and convert them to datetime objects
timestamps = pd.to_datetime(df['key.frame_timestamp_micros'], unit='us')

# Create the plot
plt.plot(timestamps, df.index)
plt.xlabel('Timestamp')
plt.ylabel('Index')
plt.show()

# %%
import matplotlib.pyplot as plt

# Extract the x, y, and z coordinates from the transform column of the DataFrame
x_coords = [row[0] for row in df['[VehiclePoseComponent].world_from_vehicle.transform']]
y_coords = [row[1] for row in df['[VehiclePoseComponent].world_from_vehicle.transform']]
z_coords = [row[2] for row in df['[VehiclePoseComponent].world_from_vehicle.transform']]

# Create a scatter plot with x, y, and z coordinates
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(x_coords, y_coords, z_coords, c='r', marker='o')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
plt.show()
