# %% [markdown]
# <a href="https://colab.research.google.com/github/neehasajja/waymo-opendataset/blob/main/testing/Prejected_lidar_box.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip3 install waymo-open-dataset-tf-2-6-0

# %%
import os
import pyarrow.parquet as pq
import tensorflow as tf

# Set the path to the directory containing the parquet files
dir_path = '/content/drive/MyDrive/testing/projected_lidar_box/'
# Get a list of all the files in the directory
files = os.listdir(dir_path)

# Loop through each file and extract metadata
for filename in files:
    # Skip directories
    if os.path.isdir(os.path.join(dir_path, filename)):
        continue
        
    # Check if the file is a parquet file
    if filename.endswith('.parquet'):
        # Read the parquet file
        parquet_file = pq.ParquetFile(os.path.join(dir_path, filename))

        # Get the metadata
        metadata = parquet_file.metadata

        # Print the metadata
        print("File:", filename)
        print(metadata)
# Out:
# File: 10504764403039842352_460_000_480_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b390130>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 10980133015080705026_780_000_800_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b390360>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 14188689528137485670_2660_000_2680_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f12f1979bd0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 17792628511034220885_2360_000_2380_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b390590>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 17136775999940024630_4860_000_4880_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b3901d0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 11987368976578218644_1340_000_1360_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b390590>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 14737335824319407706_1980_000_2000_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b390220>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 18149616047892103767_2460_000_2480_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f13271f7090>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 15272375112495403395_620_000_640_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b3903b0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 2601205676330128831_4880_000_4900_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b390590>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 8688567562597583972_940_000_960_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f13271f7090>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 4140965781175793864_460_000_480_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b3901d0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 8993680275027614595_2520_000_2540_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129bf6e270>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 5026942594071056992_3120_000_3140_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b3904a0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 7247823803417339098_2320_000_2340_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f129b390540>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548
# File: 5638240639308158118_4220_000_4240_000.parquet
# <pyarrow._parquet.FileMetaData object at 0x7f12f1979bd0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 10
#   num_rows: 0
#   num_row_groups: 1
#   format_version: 2.6
#   serialized_size: 6548

# %%
import os
import pyarrow.parquet as pq
import pandas as pd

# Set the path to the directory containing the parquet files
dir_path = '/content/drive/MyDrive/testing/projected_lidar_box/'

# Get a list of all the files in the directory
files = os.listdir(dir_path)

# Loop through each file and extract metadata
for filename in files:
    # Skip directories
    if os.path.isdir(os.path.join(dir_path, filename)):
        continue
        
    # Check if the file is a parquet file
    if filename.endswith('.parquet'):
        # Read the parquet file
        parquet_file = pq.ParquetFile(os.path.join(dir_path, filename))

        # Get the table from the file
        table = parquet_file.read()

        # Convert the table to a Pandas DataFrame
        df = table.to_pandas()

        # Calculate column statistics
        statistics = df.describe()

        # Print the statistics
        print("File:", filename)
        print(statistics)
# Out:
# File: 10504764403039842352_460_000_480_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 10980133015080705026_780_000_800_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 14188689528137485670_2660_000_2680_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 17792628511034220885_2360_000_2380_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 17136775999940024630_4860_000_4880_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 11987368976578218644_1340_000_1360_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 14737335824319407706_1980_000_2000_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 18149616047892103767_2460_000_2480_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 15272375112495403395_620_000_640_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 2601205676330128831_4880_000_4900_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 8688567562597583972_940_000_960_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 4140965781175793864_460_000_480_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 8993680275027614595_2520_000_2540_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 5026942594071056992_3120_000_3140_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 7247823803417339098_2320_000_2340_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN
# File: 5638240639308158118_4220_000_4240_000.parquet
#        key.frame_timestamp_micros  key.camera_name  \
# count                         0.0              0.0
# mean                          NaN              NaN
# std                           NaN              NaN
# min                           NaN              NaN
# 25%                           NaN              NaN
# 50%                           NaN              NaN
# 75%                           NaN              NaN
# max                           NaN              NaN
#
#        [ProjectedLiDARBoxComponent].box.center.x  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.center.y  \
# count                                        0.0
# mean                                         NaN
# std                                          NaN
# min                                          NaN
# 25%                                          NaN
# 50%                                          NaN
# 75%                                          NaN
# max                                          NaN
#
#        [ProjectedLiDARBoxComponent].box.size.x  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].box.size.y  \
# count                                      0.0
# mean                                       NaN
# std                                        NaN
# min                                        NaN
# 25%                                        NaN
# 50%                                        NaN
# 75%                                        NaN
# max                                        NaN
#
#        [ProjectedLiDARBoxComponent].type
# count                                0.0
# mean                                 NaN
# std                                  NaN
# min                                  NaN
# 25%                                  NaN
# 50%                                  NaN
# 75%                                  NaN
# max                                  NaN

# %%
import pyarrow as pa

# Load the metadata file as a binary
with open('_metadata', 'rb') as f:
    metadata_binary = f.read()

# Deserialize the metadata binary
metadata_dict = pa.deserialize(metadata_binary)

# Print the metadata dictionary
print(metadata_dict)

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
import os

os.chdir('/content/drive/MyDrive/testing/projected_lidar_box')
import pyarrow as pa

# Load the metadata file as a binary
with open('_metadata', 'rb') as f:
    metadata_binary = f.read()

# Deserialize the metadata binary
metadata_dict = pa.deserialize(metadata_binary)

# Print the metadata dictionary
print(metadata_dict)

# %%
import os

metadata_file_path = '/content/drive/MyDrive/testing/projected_lidar_box/_metadata'

# Get the size of the metadata file in bytes
metadata_file_size = os.path.getsize(metadata_file_path)

print(f"Size of metadata file: {metadata_file_size} bytes")
# Out:
# Size of metadata file: 24181 bytes

# %%
import os
import pyarrow as pa

os.chdir('/content/drive/MyDrive/testing/projected_lidar_box')

# Load the metadata file as binary
with open('_metadata', 'rb') as f:
    metadata_binary = f.read()

# Deserialize the metadata binary
metadata_dict = pa.deserialize(metadata_binary)

# Print the metadata dictionary
print(metadata_dict)
